# %% [markdown]
# <a href="https://colab.research.google.com/github/Sudip-Paul-03/Credit_Card_Default_Prediction_Capstone_Project/blob/main/Capstone_Project_On_Credit_Card_Default_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -
#
#
# # **Credit Card Default Prediction Using Supervised Machine Learning Algorithm**

# %% [markdown]
# ![lovepik-mobile-credit-card-payment-png-image_401699914_wh1200.png](data:image/png;base64,...)

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
# ##### **Project By -** SUDIP PAUL

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ## In the fast-paced world of personal finance, one of the most critical tools at our disposal is the ability to predict and manage credit card defaults. Imagine this as a watchful guardian angel, tirelessly working behind the scenes to protect your financial well-being. Credit card default prediction is that guardian angel, a sophisticated process that has a profound impact on the everyday lives of credit card users and the financial stability of lending institutions.
#
# ## Think of credit cards as your trusty companions in the financial journey, offering unparalleled convenience in managing expenses, from daily purchases to occasional splurges. But as with any journey, there are risks, both for you as a cardholder and for the companies that issue these cards.
#
# ## For cardholders, it's a balance between enjoying the convenience and the risk of late payments, mounting interest charges, and potential harm to your credit score if you mismanage your credit card debt. On the other side of the coin, credit card companies bear the responsibility of managing the risk associated with potential defaults, a challenge that's addressed through credit card default prediction.
#
# ## At its core, this process seeks to answer a fundamental question: What are the chances that a cardholder might struggle to make their credit card payments on time? It's a pivotal question, and the answer is derived from a wealth of historical data, including your transaction records, credit scores, and personal information. Complex predictive models are then constructed from this treasure trove of data, empowering financial institutions to evaluate the risk profile of each cardholder.
#
# ## These predictive models are nothing short of modern marvels, tapping into the power of data and advanced algorithms to provide invaluable insights and probabilities. They consider numerous factors that can influence your ability to keep up with payments. Among these are your payment history, credit utilization, income, employment status, age, and even where you live. All these factors come together to create a financial portrait of you.
#
# ## Once these predictive models are brought to life, financial institutions can make informed decisions to minimize potential losses. For instance, they can adjust credit limits, interest rates, or in some cases, they may choose to decline credit applications from those who present a higher risk. Importantly, these models help institutions tailor their approach to different customer segments, ensuring that they provide the right products and services to the right individuals.
#
# ## But the impact of credit card default prediction doesn't stop at the doors of financial institutions. For you, the cardholder, it becomes a trusted friend who provides you with valuable insights and early warning signs. This support helps you avoid late fees, interest rate hikes, and credit score troubles, enabling you to steer your financial ship towards safer shores.
#
# ## What's even more impressive is that credit card default prediction is not a one-off effort. It's an ongoing process, adapting to your changing financial behavior, economic shifts, and the evolving landscape. Just like life isn't static, these predictive models evolve to ensure they continue to provide accurate risk assessments that align with your current situation.
#
# ## In conclusion, credit card default prediction isn't just a financial tool; it's a vital part of your financial journey. It's like a caring guardian angel that not only watches over your shoulder but also offers guidance and support, helping you make informed financial decisions. As we dive deeper into this intriguing process, we'll explore how it works, why it matters, and how it shapes the financial landscape, ensuring a smoother and more secure journey for everyone involved.

# %% [markdown]
# # **Dataset Information**

# %% [markdown]
# ## This research employed a binary variable, default payment (Yes = 1, No = 0), as the response variable. This study reviewed the literature and used the following 23 variables as explanatory variables:
# ## X1: Amount of the given credit (NT dollar): it includes both the individual consumer credit and his/her family (supplementary) credit.
# ## X2: Gender (1 = male; 2 = female).
# ## X3: Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).
# ## X4: Marital status (1 = married; 2 = single; 3 = others).
# ## X5: Age (year).
# ## X6 - X11: History of past payment. We tracked the past monthly payment records (from April to September, 2005) as follows: X6 = the repayment status in September, 2005; X7 = the repayment status in August, 2005; . . .;X11 = the repayment status in April, 2005. The measurement scale for the repayment status is: -1 = pay duly; 1 = payment delay for one month; 2 = payment delay for two months; . . .; 8 = payment delay for eight months; 9 = payment delay for nine months and above.
# ## X12-X17: Amount of bill statement (NT dollar). X12 = amount of bill statement in September, 2005; X13 = amount of bill statement in August, 2005; . . .; X17 = amount of bill statement in April, 2005.
# ## X18-X23: Amount of previous payment (NT dollar). X18 = amount paid in September, 2005; X19 = amount paid in August, 2005; . . .;X23 = amount paid in April, 2005.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Sudip-Paul-03/Credit_Card_Default_Prediction_Capstone_Project

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# ## This project is aimed at predicting the case of customers default payments in Taiwan. From the perspective of risk management, the result of predictive accuracy of the estimated probability of default will be more valuable than the binary result of classification - credible or not credible clients. We can use the K-S chart to evaluate which customers will default on their credit card payments.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Imporing all the necessary libraries

#Import Packages and modules
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Mount the drive
from google.colab import drive
drive.mount('/content/drive', force_remount= True)
# Out:
# Mounted at /content/drive

# %%
# Create the filepath
file_path = '/content/drive/MyDrive/AlmaBetter/Capstone/Classification Project On Credit Card Default Prediction/default of credit card clients.xls'

# %%
# Load the datset
df = pd.read_excel(file_path, skiprows= 1)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset head

df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#Dataset tail

df.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

print('Dataset have {} rows and {} columns'.format(df.shape[0], df.shape[1]))
df.shape
# Out:
# Dataset have 30000 rows and 25 columns
# (30000, 25)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          30000 non-null  int64
#  1   LIMIT_BAL                   30000 non-null  int64
#  2   SEX                         30000 non-null  int64
#  3   EDUCATION                   30000 non-null  int64
#  4   MARRIAGE                    30000 non-null  int64
#  5   AGE                         30000 non-null  int64
#  6   PAY_0                       30000 non-null  int64
#  7   PAY_2                       30000 non-null  int64
#  8   PAY_3                       30000 non-null  int64
#  9   PAY_4                       30000 non-null  int64
#  10  PAY_5                       30000 non-null  int64
#  11  PAY_6                       30000 non-null  int64
#  12  BILL_AMT1                   30000 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

No_of_duplicate_rows=df[df.duplicated()].shape[0]
print(f'we hve total no {No_of_duplicate_rows} duplicate rows.')
# Out:
# we hve total no 0 duplicate rows.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

df.isna().sum().sort_values(ascending=False)[:].reset_index().rename(columns = {'index':'columns',0:'null values'})
# Out:
#                        columns  null values
# 0                           ID            0
# 1                    BILL_AMT2            0
# 2                     PAY_AMT6            0
# 3                     PAY_AMT5            0
# 4                     PAY_AMT4            0
# 5                     PAY_AMT3            0
# 6                     PAY_AMT2            0
# 7                     PAY_AMT1            0
# 8                    BILL_AMT6            0
# 9                    BILL_AMT5            0
# 10                   BILL_AMT4            0
# 11                   BILL_AMT3            0
# 12                   BILL_AMT1            0
# 13                   LIMIT_BAL            0
# 14                       PAY_6            0
# 15                       PAY_5            0
# 16                       PAY_4            0
# 17                       PAY_3            0
# 18                       PAY_2            0
# 19                       PAY_0            0
# ...

# %%
# Visualizing the missing values

# Creating a new dataset of number of non-null values in each column
Non_null_df = df.notnull().sum().reset_index().rename(columns = {'index' : 'columns', 0 : "Non-Null Values"})

# Plotting of the Non-null-df
ax = Non_null_df.plot(kind = 'barh', x = 'columns', figsize=(12,6))

#Labelling of each bars in the plot
ax.bar_label(ax.containers[0])

#Set x-axis labels and y-axis labels
plt.ylabel('Columns', {'fontsize': 12, 'fontweight': 15})
plt.xlabel("Non Null Values", {'fontsize': 12, 'fontweight': 15})
plt.legend(title="Non-Null Values", bbox_to_anchor=(1.05, 1), loc=2)
#set plot title
plt.title('Column-wise Non-null Values',{'fontsize': 18, 'fontweight': 20})
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * We have a total of 3000 rows and 25 columns in our dataset.
# * We have no duplicated rows, missing values/null vales in our dataset, which makes the dataset easier to work with.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

print('Total Features present in the dataset:', df.columns )
# Out:
# Total Features present in the dataset: Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
# Dataset Describe

df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# We have records of 30000 customers. Below are the description of all features we have.
#
# * ID: ID of each client
#
# * LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit)
#
# * SEX: Gender (1 = male, 2 = female)
#
# * EDUCATION: (1 = graduate school, 2 = university, 3 = high school, 0,4,5,6 = others)
#
# * MARRIAGE: Marital status (0 = others, 1 = married, 2 = single, 3 = others)
#
# * AGE: Age in years
#
# * Scale for PAY_0 to PAY_6 : (-2 = No consumption, -1 = paid in full, 0 = use of revolving credit (paid minimum only), 1 = payment delay for one month, 2 = payment delay for two months, ... 8 = payment delay for eight months, 9 = payment delay for nine months and above)
#
# * PAY_0: Repayment status in September, 2005 (scale same as above)
#
# * PAY_2: Repayment status in August, 2005 (scale same as above)
#
# * PAY_3: Repayment status in July, 2005 (scale same as above)
# PAY_4: Repayment status in June, 2005 (scale same as above)
#
# * PAY_5: Repayment status in May, 2005 (scale same as above)
#
# * PAY_6: Repayment status in April, 2005 (scale same as above)
#
# * BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
#
# * BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
#
# * BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
#
# * BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
#
# * BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
#
# * BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
#
# * PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
#
# * PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
#
# * PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
#
# * PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
#
# * PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
#
# * PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
#
# * default.payment.next.month: Default payment (1=yes, 0=no)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

def unique_values(dF):
    unique_vals = []
    for col in dF.columns:
        unique_vals.append(dF[col].unique())

    return unique_vals

print(unique_values(df))
# Out:
# [array([    1,     2,     3, ..., 29998, 29999, 30000]), array([  20000,  120000,   90000,   50000,  500000,  100000,  140000,
#         200000,  260000,  630000,   70000,  250000,  320000,  360000,
#         180000,  130000,  450000,   60000,  230000,  160000,  280000,
#          10000,   40000,  210000,  150000,  380000,  310000,  400000,
#          80000,  290000,  340000,  300000,   30000,  240000,  470000,
#         480000,  350000,  330000,  110000,  420000,  170000,  370000,
#         270000,  220000,  190000,  510000,  460000,  440000,  410000,
#         490000,  390000,  580000,  600000,  620000,  610000,  700000,
#         670000,  680000,  430000,  550000,  540000, 1000000,  530000,
#         710000,  560000,  520000,  750000,  640000,   16000,  570000,
#         590000,  660000,  720000,  327680,  740000,  800000,  760000,
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Renaming the default payment next month column for better convenience

df.rename(columns={'default payment next month' : 'default_payment_next_month'}, inplace=True)

# %%
print('Fraud Cases: {}'.format(len(df[df['default_payment_next_month'] == 1])))
print('Valid Transactions: {}'.format(len(df[df['default_payment_next_month'] == 0])))
# Out:
# Fraud Cases: 6636
# Valid Transactions: 23364

# %%
# Renaming other columns names such as "PAY", "BILL AMT" and "PAY_AMT" to their respective month names

df.rename(columns={'PAY_0':'PAY_SEPT','PAY_2':'PAY_AUG','PAY_3':'PAY_JUL','PAY_4':'PAY_JUN','PAY_5':'PAY_MAY','PAY_6':'PAY_APR'},inplace=True)
df.rename(columns={'BILL_AMT1':'BILL_AMT_SEPT','BILL_AMT2':'BILL_AMT_AUG','BILL_AMT3':'BILL_AMT_JUL','BILL_AMT4':'BILL_AMT_JUN','BILL_AMT5':'BILL_AMT_MAY','BILL_AMT6':'BILL_AMT_APR'}, inplace = True)
df.rename(columns={'PAY_AMT1':'PAY_AMT_SEPT','PAY_AMT2':'PAY_AMT_AUG','PAY_AMT3':'PAY_AMT_JUL','PAY_AMT4':'PAY_AMT_JUN','PAY_AMT5':'PAY_AMT_MAY','PAY_AMT6':'PAY_AMT_APR'}, inplace = True)

# %%
# Differentiating the numerical and categorical features
categorical_features = [i for i in df.columns if df[i].nunique()<=4]
numeric_features = [i for i in df.columns if i not in categorical_features]

print("The categorical features in this dataset are:", categorical_features)
print("The numeric features in this dataset are:", numeric_features)
# Out:
# The categorical features in this dataset are: ['SEX', 'MARRIAGE', 'default_payment_next_month']
# The numeric features in this dataset are: ['ID', 'LIMIT_BAL', 'EDUCATION', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %%
# Counting the total marriage status

df['MARRIAGE'].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      323
# 0       54
# Name: MARRIAGE, dtype: int64

# %%
# Combine 0 and 3 by changing the value 0 into others

df["MARRIAGE"] = df["MARRIAGE"].replace({0:3})
df["MARRIAGE"].value_counts()
# Out:
# 2    15964
# 1    13659
# 3      377
# Name: MARRIAGE, dtype: int64

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * We have renamed our column 'default payment next month' to 'default_payment_next_month' column for better convenience of our project and also we have seen the number of Fraud cases and valid transaction from this column as well.
# * We have also renamed other columns such as other columns names such as "PAY", "BILL AMT" and "PAY_AMT" to their respective month names.
# * We have separated catagorical features from the numerical features in the dataset as well.
# * We have an value 0 in the Marriage column which is unknown to us and as the count of zero is very less as compared to the other columns, we have combined that with the others column for the ease of our model.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 : Distribution of Fraud Cases and Valid transactions

# %%
# Chart- 1: Distribution of fraud cases and valid transactions

# set figure size
plt.figure(figsize=(10,5))

# Set up the plot title
plt.title('Count of Fraud and Valid Transactions', {'fontsize': 18, 'fontweight': 20})

# Plot the countplot
fig1 = sns.countplot(x = 'default_payment_next_month', data = df)

# labels for each bar
for container in fig1.containers:
    fig1.bar_label(container)

# set x-axis and y-axis labels
plt.xlabel("Default payment Next Month", {'fontsize': 12, 'fontweight': 15})
plt.ylabel("Count", {'fontsize': 12, 'fontweight': 15})

# display figure
plt.show()

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we have found there are two classes present:
#
# *   0 : Not Defaulters
# *   1 : Defaulters
#
# We can see that, there is an imbalance in the dataset so we need to normalize that.

# %% [markdown]
# #### Chart - 2 : No of Customers in Different Sex Group

# %%
# Chart - 2: No of customers in different sex groups

# set figure size
plt.figure(figsize=(10,5))

# Set up the plot title
plt.title('No of customers in different Sex groups', {'fontsize': 18, 'fontweight': 20})

# Plot the countplot
fig2 = sns.countplot(x = 'SEX', data = df)

# labels for each bar
for container in fig2.containers:
    fig2.bar_label(container)

# set x-axis and y-axis labels
plt.xlabel("Sex Groups", {'fontsize': 12, 'fontweight': 15})
plt.ylabel("Count", {'fontsize': 12, 'fontweight': 15})

# display figure
plt.show()

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# Here in this dataset,
# * 1 : Male
# * 2 : Female
#
# So, we can see there are more female credit card holders than male credit card holders.

# %% [markdown]
# #### Chart - 3 : Marital Status of Credit Card Holders

# %%
# Chart - 3 : Marital status of credit card holders

# set figure size
plt.figure(figsize=(10,5))

# Set up the plot title
plt.title('No of customers in different Marital groups', {'fontsize': 18, 'fontweight': 20})

# Plot the countplot
fig3 = sns.countplot(x = 'MARRIAGE', data = df)

# labels for each bar
for container in fig3.containers:
    fig3.bar_label(container)

# set x-axis and y-axis labels
plt.xlabel("Marital Groups", {'fontsize': 12, 'fontweight': 15})
plt.ylabel("Count", {'fontsize': 12, 'fontweight': 15})

# display figure
plt.show()

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above data analysis we can say that
#
# * 1 : married
# * 2 : single
# * 3 : others
#
# 'Single' credit cards holders are more in number as compared to the other marital groups.

# %% [markdown]
# #### Chart - 4 : Distribution of Card holders in Different Ages

# %%
# Chart - 4 : Distribution of credit card holders in different ages

# Plotting the count plot to vizualize the data distribution
fig4 = px.histogram(df, x = 'AGE', marginal = 'box',
                    title = 'Distribution of Age of card holder',
                    labels = {'x': 'Dollar($)', 'y': 'Nuumber of card'},
                   color_discrete_sequence=px.colors.qualitative.D3,
                   nbins = 75)

# Updating the data to show the distribution clearly
fig4.update_traces(marker_line_width=1,marker_line_color="white")

# Show figure
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# We can see that the the number of people who are aged 29 use credit card the most and it is mostly used by the people within the 23-42 years age range while, the number of people having credit card at age 60+ or more is very less.

# %% [markdown]
# #### Chart - 5 : Distribution of Credit Card Holders with Different Credit Limits

# %%
# Chart - 5 : Distribution of credit card holders in different credit card Limit

# Plotting the count plot to vizualize the data distribution
fig5 = px.histogram(df, x = 'LIMIT_BAL', marginal = 'box',
                    title = 'Distribution of balance limit of card',
                    labels = {'x': 'Dollar($)', 'y': 'Novmber of card'},
                   color_discrete_sequence=px.colors.qualitative.Antique)

# Updating the data to show the distribution clearly
fig5.update_traces(marker_line_width=1,marker_line_color="white")

# Show figure
fig5.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### What is/are the insight(s) found from the chart?

# %% [markdown]
# * From this chart we can see that the most common limit balance is $50K.
#
# * While the highest limit Balance is $550K.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# Answer Here.

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
